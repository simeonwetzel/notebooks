# %% [markdown]
# <a href="https://colab.research.google.com/github/simeonwetzel/notebooks/blob/main/Eartharxiv_LLM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Requirements
#
# - Osf-token for fetching records from eartharxiv --> Get osf-token here: https://osf.io/
#
# - Groq API-key for LLM inference --> Get free acount and API-key here: https://groq.com/

# %%
from getpass import getpass

osf_token = getpass("OSF_TOKEN=")
# Out:
# OSF_TOKEN=··········

# %%
import os
os.environ["GROQ_API_KEY"] = getpass("Enter your Groq API key: ")
# Out:
# Enter your Groq API key: ··········

# %% [markdown]
# Install necessary packages:

# %%
# !pip install -qU langchain-groq

# %% [markdown]
# #1. Download eartharxiv dump

# %%
import requests
from tqdm import tqdm

def fetch_all_preprints(base_url: str, params: dict):
    all_records = []  # This will hold all collected records
    page = 1  # Start from the first page
    total_pages = 1  # Initialize total_pages (will update based on response)

    # First request to find the total number of pages (if available)
    response = requests.get(url=base_url, params=params)
    if response.status_code != 200:
        print(f"Error fetching data: {response.status_code}")
        return []

    data = response.json()
    total_pages = data['links']['meta']['total'] / 10 # Update with the actual total pages

    # Now we know the total number of pages, so we can create the tqdm progress bar
    with tqdm(total=total_pages, desc="Fetching preprints") as pbar:
        while True:
            # Add pagination to the params
            params['page'] = page

            # Make the GET request
            response = requests.get(url=base_url, params=params)

            if response.status_code != 200:
                print(f"Error fetching data: {response.status_code}")
                break

            # Get the records from the response
            data = response.json()
            preprints = data['data']  # Assuming 'data' holds the records

            # Append the preprints to the all_records list
            all_records.extend(preprints)

            # Check if there is another page
            if 'next' not in data['links']:
                break  # No next page, we are done

            page += 1  # Move to the next page
            pbar.update(1)  # Update the progress bar for each page

    return all_records

# Example usage:
base_url = "https://api.osf.io/v2/preprints/"
params = {"filter[provider]": "eartharxiv"}

headers = {'Content-Type': 'application/json',
          'Authorization': 'Bearer {0}'.format(osf_token)}

# Fetching the preprints with the progress bar
all_preprints = fetch_all_preprints(base_url, params)

# Now all_preprints holds all the records
print(f"Total records fetched: {len(all_preprints)}")
# Out:
# Fetching preprints:  99%|█████████▉| 164/164.9 [01:29<00:00,  1.70it/s]/usr/local/lib/python3.10/dist-packages/tqdm/std.py:636: TqdmWarning: clamping frac to range [0, 1]
#   full_bar = Bar(frac,
# Fetching preprints: 100%|██████████| 165/164.9 [01:30<00:00,  1.83it/s]
# Error fetching data: 404
# Total records fetched: 1649

# %% [markdown]
# #2. Extract spatial context with LLM

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    model="llama3-8b-8192",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2,
)

# %%
from langchain_core.output_parsers import JsonOutputParser
from langchain_core.pydantic_v1 import BaseModel, Field
from langchain_core.prompts import PromptTemplate
from langchain_core.exceptions import OutputParserException
from langchain.output_parsers import OutputFixingParser

class LocationContext(BaseModel):
    location: str = Field(description="A location. Can be a city, region, country or a continent.")
    bbox: list[str] = Field(description="Bounding Box in format [ymin, xmin, ymax, xmax]")

parser = JsonOutputParser(pydantic_object=LocationContext)

output_fixer = OutputFixingParser.from_llm(parser=parser, llm=llm)

prompt = PromptTemplate(
    template="""You are an expert in extracting the geographic references.
            Your task is to extract the location reference with a bounding box [ymin, xmin, ymax, xmax] that is most suitable to the revieced text.

            Format instructions: {format_instructions}

            Do not generate further textual explanations. Only output a JSON with location and bbox. Leave JSON values empty where you can't extract the information.
            Query: {input}
            """,
    input_variables=["input"],
    partial_variables={"format_instructions": parser.get_format_instructions()},
)

chain = prompt | llm

def extract_spatial_reference(input_text: str):
  output = chain.invoke(
      {
          "input": input_text,
      }
  )
  try:
    parsed_output = parser.parse(output.content)
  except OutputParserException as e:
    print(f"Output parsing failed. Trying to fix format.")
    print(f"Misformed output: {output.content}")
    parsed_output = output_fixer.parse(output.content)

  return parsed_output

# %%
# Function to get the title and abstract of a metadata record
def format_title_abstract(doc: dict) -> str:
  return f"{doc['attributes']['title']}: {doc['attributes']['description']}"

# %% [markdown]
# ###3. Apply LLM chain to all fetched preprints

# %%
from tqdm import tqdm

def apply_spatial_referencing(preprints: list[dict]) -> list[dict]:
  updated_preprints = []
  for x in tqdm(preprints, desc="Extracting spatial context"):
      updated_preprints.append({**x, "spatial_context": extract_spatial_reference(format_title_abstract(x))})
  return updated_preprints

# %% [markdown]
# We test the function here with a subset of 50 records.

# %%
subset_preprints = apply_spatial_referencing(preprints=all_preprints[:50])
# Out:
# Extracting spatial context: 100%|██████████| 50/50 [00:53<00:00,  1.08s/it]

# %% [markdown]
# #4. Display parsed information as pandas dataframe

# %%
formatted_dict = list(map(lambda x: {'id': x['id'],
                                     'title': x['attributes']['title'],
                                     'description': x['attributes']['description'],
                                     'AI_parsed_location': x['spatial_context']['location'] if x['spatial_context']['location'] else None,
                                     'AI_parsed_BBOX': x['spatial_context']['bbox'] if (x['spatial_context']['bbox'] and not any(item == '' for item in x['spatial_context']['bbox'])) else None}, subset_preprints))

# %%
import pandas as pd

df = pd.DataFrame(formatted_dict)
df
# Out:
#        id                                              title  \
# 0   2p9wg  Uncertainties in Projected Rainfall over Brazi...
# 1   eayph  What does the NDVI really tell us about crops?...
# 2   n8hz7  A continental-scale assessment of density, siz...
# 3   g2uxy  Structure and age relationship of joint sets o...
# 4   ktcde  An analytical solution to the Navier–Stokes eq...
# 5   qhtb6  The composition and weathering of the continen...
# 6   t8dm4  GARPOS: analysis software for the GNSS-A seafl...
# 7   2rxbn  Quantification of non-linear multiphase flow i...
# 8   huz73  Correcting 19th and 20th century sea surface t...
# 9   ju26e  Identifying and correcting the World War 2 war...
# 10  ksqhy  The Ediacaran Grenville dykes (SE Canada) reve...
# 11  gu9rx  A unifying basis for the interplay of stress a...
# 12  kxqsc     A prototype for a Multi-GNSS orbit combination
# 13  9s7y6  Quantitative estimates of average geomagnetic ...
# 14  68zc4  An Integrated Flood Risk Assessment and Mitiga...
# 15  5tghq  Computing single-particle flotation kinetics u...
# 16  f2zxh  Comment: The effect of post-conflict transitio...
# 17  a9gd6  Structure of the North Anatolian Fault Zone im...
# 18  bryje  Citizen science reveals the population exposur...
# 19  h7cjd  Evolution of normal fault displacement and len...
# 20  evgpj  Resolving the Kinematics and Moment Release of...
# 21  9snjm  Rapid finite-frequency microseismic noise sour...
# 22  mx39v  Apatite fission-track dating by LA-Q-ICP-MS ma...
# 23  n6tv2  Marine mineral-catalyzed NO and N2O formation ...
# 24  bh43s  On the Evolution of Thermally Stratified Layer...
# 25  x7v4e  Unequal anthropogenic enrichment of mercury in...
# 26  fj3w4  The 23 June 2020, Mw 7.4 La Crucecita, Oaxaca,...
# 27  zw5n4  A data-driven approach for characterizing comm...
# 28  3cxqz  Multiple Small Scale Landslides Triggered by T...
# 29  uevsx  A Statistical Evaluation of WRF-LES Trace Gas ...
# 30  z4cju  Diversity Crisis in UK Geoscience Research Tra...
# 31  4ckpg  Use of geochemical and ecotoxicological approa...
# 32  6gw27  Three-Station Interferometry and Tomography: C...
# 33  2yha5  Wayfinding and Accessibility Analysis for Crit...
# 34  vgf5e            Fernandes and Roberts (2020) - preprint
# 35  ch8xf  Bridging the gap between geophysics and geolog...
# 36  e5avq  Web-based Data Analytics Framework for Well Fo...
# 37  yc49t  A Comprehensive Flood Event Specification and ...
# 38  s9263  Stress, rigidity and sediment strength control...
# 39  mc6np  Variability of headwater stream network extent...
# 40  ks2yz  GeospatialVR: A Web-based Virtual Reality Fram...
# 41  p4mnb  Isotropic and Azimuthally Anisotropic Rayleigh...
# 42  yreqw  A Source Clustering Approach for Efficient Inu...
# 43  3rk2y  Bedload transport in rivers: size matters but ...
# 44  5usv7  Taking the pulse of salt-detached gravity glid...
# 45  v9fj8  Leaky salt: pipe trails record the history of ...
# 46  j3pu6  Hydrogeologic and Geochemical Distinctions in ...
# 47  ajmgy     Principal component analysis of seismic facies
# 48  rdv2s  Paucity of legacy oil and gas subsurface data ...
# 49  234kp    Notes on Seismic Source Models in Elastostatics
#
#                                           description  \
# 0   The aim of this study is to answer four main q...
# 1   The use of remote sensing in agriculture is ex...
# 2   Farm dams are a cornerstone of modern agricult...
# 3   Outcrop studies of fracture networks are impor...
# 4   This paper is concerned with obtaining a formu...
# 5   The composition of continental crust records a...
# 6   Global Navigation Satellite System – Acoustic ...
# 7   We measure the pressure difference during two-...
# 8   Changes in the statistics of North Atlantic hu...
# 9   Most foregoing estimates of historical sea sur...
# 10  Long-term variations of the geomagnetic field,...
# 11  The Earth is under stress on all scales from i...
# 12  Since 1994, the International GNSS Service (IG...
# 13  A defining characteristic of the recent geomag...
# 14  Property buyout is one of the most frequently ...
# 15  Flotation kinetic studies are essential for pr...
# 16  A recent study on Colombian protected areas ha...
# 17  Information on fault zone structure is essenti...
# 18  Air pollution remains a key environmental prob...
# 19  Continental rifting is accommodated by the dev...
# 20  Continuous measurements of postseismic surface...
# 21  Ambient noise cross-correlations can be used a...
# 22  Obtaining accurate and precise apatite fission...
# 23  Microbial metabolisms were limited by availabl...
# 24  Stable stratification at the top of the Earth’...
# 25  Remote northern (NH) and southern hemisphere (...
# 26  The 23 June 2020 La Crucecita earthquake occur...
# 27  This study elucidates PM2.5 exposure dispariti...
# 28  Devastating landslides can cause significant d...
# 29  In recent years, new measurement systems have ...
# 30  Geoscientists have a key role to play in the g...
# 31  We compared sediment quality in estuaries at t...
# 32  Traditional two-station ambient noise interfer...
# 33  Transportation infrastructure plays an essenti...
# 34  There are many geoscience problems for which c...
# 35  Inverse mapping from geophysics to geology is ...
# 36  Groundwater supplies drinking water for over o...
# 37  Flooding is one of the most frequent natural d...
# 38  Megathrust faults host the largest earthquakes...
# 39  Stream networks expand and contract through ti...
# 40  This research introduces GeospatialVR, an open...
# 41  We use data from the Cascadia Initiative (CI) ...
# 42  For coastal regions on the margin of a subduct...
# 43  Bedload transport modelling in rivers, which d...
# 44  We investigate early-stage salt-detached glidi...
# 45  Despite salt being regarded as an extremely ef...
# 46  The Salar de Atacama contains one of the world...
# 47  Seismic facies analyses are fundamental to the...
# 48  The decarbonisation of energy systems to achie...
# 49  Seismic source models in elastostatics lay the...
#
#                                    AI_parsed_location  \
# 0                                              Brazil
# 1                                                None
# 2                                           Australia
# 3                                Lilstock Benches, UK
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                      North Atlantic
# 9                                                None
# 10                                          SE Canada
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               Iowa
# 15                                               None
# 16                                           Colombia
# 17                                             Turkey
# 18                                               None
# 19                                          Australia
# 20                                           Kumamoto
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                       Earth's Core
# 25                                               None
# 26                                     Oaxaca, Mexico
# 27                                               None
# 28                                              Japan
# 29                                               None
# 30                                                 UK
# 31                            São Paulo State, Brazil
# 32                                               None
# 33                                               Iowa
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41    Juan de Fuca and Gorda Plates and U.S. Cascadia
# 42  [Cascadia Subduction Zone, Crescent City, CA, ...
# 43                                             rivers
# 44                              Eastern Mediterranean
# 45                Levant Basin, Eastern Mediterranean
# 46                                   Salar de Atacama
# 47                                               None
# 48                                     United Kingdom
# 49                                               None
#
#                             AI_parsed_BBOX
# 0                  [-22.5, -75, 10.5, -30]
# 1                                     None
# 2              [-44.1, 112.9, -9.1, 154.0]
# 3       [51.4374, 3.1544, 51.4574, 3.1744]
# 4                                     None
# 5                                     None
# 6                                     None
# 7                                     None
# 8               [25.0, -75.0, 50.0, -40.0]
# 9                                     None
# 10                   [50.2,60.2,56.5,66.5]
# 11                                    None
# 12                                    None
# 13                                    None
# 14              [39.5, -94.5, 43.5, -89.5]
# 15                                    None
# 16                [null, null, null, null]
# 17               [39.7, -31.9, 41.7, 33.9]
# 18                                    None
# 19            [24.5, -116.5, 24.5, -114.5]
# 20  [32.8083, 130.6739, 33.2408, 131.0831]
# 21                                    None
# 22                                    None
# 23                                    None
# 24    [unknown, unknown, unknown, unknown]
# 25                                    None
# 26              [16.5, -96.5, 18.5, -95.5]
# 27                                    None
# 28  [34.583333, 138.25, 36.583333, 141.25]
# 29                                    None
# 30                                    None
# 31          [-25.00, -50.00, 30.00, 50.00]
# 32                                    None
# 33                                    None
# 34                                    None
# 35                                    None
# 36                                    None
# 37   [37.9538, -36.1535, 39.5965, 43.4115]
# 38                                    None
# 39                                    None
# 40                                    None
# 41            [43.7, -125.4, 47.3, -120.8]
# 42            [45.5, -125.5, 48.5, -123.5]
# 43                                    None
# 44               [34.5, -35.5, 37.5, 30.5]
# 45               [33.5, -35.5, 36.5, 37.5]
# 46              [-23.3, -70.5, -23, -70.2]
# 47                                    None
# 48                 [55.5, -6.5, 60.5, 2.5]
# 49                                    None
